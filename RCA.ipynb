# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import zipfile

# %% [markdown]
# # Get the Data

# %%
import time
start = time.time()

tr_set1 = pd.read_sas(r"R:\Data\retail lending\ThomasS\RCA\Dataset\dataset_201802.sas7bdat")

end = time.time()
print(end - start)
# Out:
# 158.29900002479553

# %% [markdown]
# # Discover and visualize the data to gain insights

# %%
tr_set1.head()
# Out:
#         Account_Num Product_Code First_Use_Code Account_Stat_Code  \
# 0  b'3792400000385'       b'AXS'           b'1'              b'5'
# 1  b'3792400000419'       b'AXS'           b'1'              b'5'
# 2  b'3792400000435'       b'AXS'           b'1'              b'5'
# 3  b'3792400000443'       b'AXS'           b'2'              b'5'
# 4  b'3792400000450'       b'AXS'           b'1'              b'5'
#
#   Block_Reclass_Code Opened_Date  Credit_Lim  Mths_Delq  Tot_Delq  \
# 0                NaN  2012-09-24      7500.0        0.0       0.0
# 1                NaN  2012-09-24      4000.0        0.0       0.0
# 2                NaN  2012-09-24      6500.0        0.0       0.0
# 3                NaN  2012-09-24      1900.0        0.0       0.0
# 4                NaN  2012-09-24      7500.0        0.0       0.0
#
#    Orig_Chrg_Off_Amt Chrg_Off_Date  Amt_Last_Payt  Purch_Int_Rate  \
# 0                0.0           NaT          50.00        0.000548
# ...

# %%
tr_set1.describe()
# Out:
#          Credit_Lim     Mths_Delq      Tot_Delq  Orig_Chrg_Off_Amt  \
# count  3.274284e+06  3.274284e+06  3.274284e+06          3274284.0
# mean   2.299427e+04  4.495823e-01  4.796979e+00                0.0
# std    5.646941e+04  2.087592e+00  2.734990e+02                0.0
# min    1.000000e+00  0.000000e+00  0.000000e+00                0.0
# 25%    5.000000e+03  0.000000e+00  0.000000e+00                0.0
# 50%    1.000000e+04  0.000000e+00  0.000000e+00                0.0
# 75%    2.100000e+04  0.000000e+00  0.000000e+00                0.0
# max    4.500000e+06  1.290000e+02  2.337594e+05                0.0
#
#        Amt_Last_Payt  Purch_Int_Rate   Tot_New_Bal  Tot_Min_Payt  \
# count   3.274284e+06    3.274284e+06  3.274284e+06  3.274284e+06
# mean    7.954871e+02    4.122937e-04  1.228318e+04  8.733998e+01
# std     5.188040e+03    1.910608e-04  3.861318e+04  1.574186e+02
# min     0.000000e+00    0.000000e+00  1.000000e-02  0.000000e+00
# ...
